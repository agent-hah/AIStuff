# %%
# %pip install pandas scikit-learn tensorflow keras bokeh numpy scipy
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: tensorflow in ./.venv/lib/python3.9/site-packages (2.18.0)
# Requirement already satisfied: keras in ./.venv/lib/python3.9/site-packages (3.8.0)
# Requirement already satisfied: bokeh in ./.venv/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.venv/lib/python3.9/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.9/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in ./.venv/lib/python3.9/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.9/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in ./.venv/lib/python3.9/site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in ./.venv/lib/python3.9/site-packages (from keras) (0.14.0)
# Requirement already satisfied: Jinja2>=2.9 in ./.venv/lib/python3.9/site-packages (from bokeh) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in ./.venv/lib/python3.9/site-packages (from bokeh) (1.3.0)
# Requirement already satisfied: pillow>=7.1.0 in ./.venv/lib/python3.9/site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in ./.venv/lib/python3.9/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.9/site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./.venv/lib/python3.9/site-packages (from bokeh) (2025.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (8.6.1)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (3.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, BatchNormalization, MaxPooling2D, Dropout
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool
import bokeh
import scipy
import numpy
from bokeh.plotting import output_notebook

# %%
#Creates path and filters player data so that at least 2000 minutes was played in that season
path = "AllStatsfrom2000.csv"
df = pandas.read_csv(path)
df["Total_Minutes"] = df["GP"] * df["MIN"]
df = df[df["Total_Minutes"]>=2000]
df["MIN"]
# Out:
# 2        31.5
# 3        28.5
# 9        36.6
# 10       41.9
# 12       29.2
#          ...
# 11622    27.8
# 11636    32.2
# 11637    37.5
# 11642    29.7
# 11658    31.5
# Name: MIN, Length: 2588, dtype: float64

# %%
#Gets list of every column name in dataset
columns = df.columns.to_list()

# %%
#Extra column to remove
drop_columns = ["PLAYER_ID"]

# %%
#Gets rid of every column that ends with RANK or FANTASY
#Dropped because they are unnecessary columns
df = df[[c for c in df.columns if not (c.endswith('RANK') or "FANTASY" in c)]]
df = df.drop(drop_columns,axis=1)

# %%
#Gets columns for data on person. Not required for model
index_cols = ["PLAYER_NAME","SEASON", "W_PCT","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","W","L","Total_Minutes"]

# %%
#Creates the ID as the index, and creates the personal data in its own dataset
player_columns = df[index_cols]
player_columns["ID"] = df.index
player_columns
# Out:
# /var/folders/72/1kw645xs517c38xtlrxqrw7r0000gq/T/ipykernel_75565/3895811776.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_columns["ID"] = df.index
#              PLAYER_NAME   SEASON  W_PCT NICKNAME     TEAM_ID  \
# 2            Aaron McKie  2000-01  0.671    Aaron  1610612755
# 3         Aaron Williams  2000-01  0.317    Aaron  1610612751
# 9          Allan Houston  2000-01  0.577    Allan  1610612752
# 10         Allen Iverson  2000-01  0.704    Allen  1610612755
# 12        Alvin Williams  2000-01  0.573    Alvin  1610612761
# ...                  ...      ...    ...      ...         ...
# 11622          Tre Jones  2023-24  0.273      Tre  1610612759
# 11636  Tyrese Haliburton  2023-24  0.580   Tyrese  1610612754
# 11637       Tyrese Maxey  2023-24  0.614   Tyrese  1610612755
# 11642  Victor Wembanyama  2023-24  0.268   Victor  1610612759
# 11658    Zion Williamson  2023-24  0.600     Zion  1610612740
#
#       TEAM_ABBREVIATION   W   L  Total_Minutes     ID
# 2                   PHI  51  25         2394.0      2
# 3                   NJN  26  56         2337.0      3
# 9                   NYK  45  33         2854.8      9
# 10                  PHI  50  21         2974.9     10
# 12                  TOR  47  35         2394.4     12
# ...                 ...  ..  ..            ...    ...
# 11622               SAS  21  56         2140.6  11622
# 11636               IND  40  29         2221.8  11636
# 11637               PHI  43  27         2625.0  11637
# 11642               SAS  19  52         2108.7  11642
# 11658               NOP  42  28         2205.0  11658
#
# [2588 rows x 10 columns]

# %%
#Drops the index Columns from original dataset
df = df.drop(index_cols,axis=1)

# %%
#Normalizes data to 0 and 1
df_non_normalized = df[:]
for column in df.columns.to_list():
    df[column] = (df[column] - df[column].min())/(df[column].max()-df[column].min())#Normalization

# %%
#Converts data and answers to numpy array (Like int arrays in Java and C++)
answers = player_columns["W_PCT"].to_numpy()
data = df.to_numpy()

# %%
#check the number of categories in the dataframe
len(df.keys())
# Out:
# 55

# %%
#Splits Test and Train Data
total_train_percentage = 70
train_data, test_data, train_answers, test_answers = train_test_split(
      data, answers, train_size=total_train_percentage/100, random_state=69
  )
train_answers = train_answers.reshape(-1, 1)
test_answers = test_answers.reshape(-1, 1)

# %%
#CREATE AND COMPILE MODEL HERE. Please name Model "model"
model = Sequential([
    Dense(64, activation='relu', input_shape=(data.shape[1],)), # Dense layer with 64 units
    # The dense layers are the actual neural network layers with nodes and activation functions
    Dense(32, activation='relu', name='HiddenLayer'), # Hidden layer with 64 nodes - feel free to change this hyper-parameter
    Dense(1, activation='linear')  # Output layer with 1 unit for regression
])

# The learning rate hyper-parameter controls how fast the model learns.
# Think of the learning rate as step size when trying to reach a particular optimal point
# The perfect learning rate will get you there fastest, without overshooting or taking too long
# For most applications, 0.001 or 0.0001 will work well
learning_rate = 0.001

# We need to define the loss function and optimizer for our model
# The compile() function allows the model to be trained afterward
model.compile(
    loss = MeanSquaredError(),
    optimizer = Adam(learning_rate=learning_rate)
)

# Check the dimensions of our training data to ensure it is ready to use
print(train_data.shape, train_answers.shape)

# Train the model using the fit() function for 25 epochs
# Epochs is another hyper-parameter that controls the iterations over the training data
# More epochs will fit the model closer and closer to the training data; however, too many epochs can lead to overfitting
# Overfitting occurs when a model focuses too much on the training data and not being able to generalize to the testing data
model.fit(train_data, train_answers, epochs=25)
# Out:
# (1811, 55) (1811, 1)
# Epoch 1/25
# /Users/ashmithandoo/Library/Mobile Documents/com~apple~CloudDocs/Projects/nbaAI/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.1492
# Epoch 2/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0070
# Epoch 3/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0047
# Epoch 4/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0037
# Epoch 5/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0034
# Epoch 6/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0033
# Epoch 7/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0034
# Epoch 8/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0031
# Epoch 9/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0031
# Epoch 10/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0030
# Epoch 11/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0031
# Epoch 12/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 0.0031
# Epoch 13/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0030
# Epoch 14/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032
# Epoch 15/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0031
# Epoch 16/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0029
# Epoch 17/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0030
# Epoch 18/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0028
# Epoch 19/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0027
# Epoch 20/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0029
# Epoch 21/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0029
# Epoch 22/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0030
# Epoch 23/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0029
# Epoch 24/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0026
# Epoch 25/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0025

# %%
#Plots Data
winning_percentages = list(model.predict(data))
winning_percentages = [list(i)[0] for i in winning_percentages]
winning_percentages = numpy.array(winning_percentages)

plots = []
for column in df.columns.tolist():
  column_vals = df_non_normalized[column].to_numpy()
  name = player_columns["PLAYER_NAME"].to_list()
  season = player_columns["SEASON"].to_list()
  nameAndSeason = [f"{name[i]}\n{season[i]}" for i in range(len(name))]
  slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(column_vals,winning_percentages)
  print(f"""
  {column} stats:
  Winning Percentage Change Per One: {slope*100}%
  r: {r_value}
  r^2: {r_value*r_value}
  standard deviation: {std_err}""")
  columns_vals = list(column_vals)
  winnings_percentages = list(winning_percentages)
  data = {'x': column_vals, 'y': winnings_percentages, 'labels': nameAndSeason}
  source = ColumnDataSource(data)
  # Create the plot
  p = figure(title="Interactive Plot", tools="pan,wheel_zoom,box_zoom,reset", tooltips=[("Label", "@labels"), ("(x, y)", "(@x, @y)")],x_axis_label=column,y_axis_label="Estimated Winning Percentage")
  p.scatter(x='x', y='y', size=10, source=source)
  plots.append(p)
grid = bokeh.layouts.column(plots)  # Arranged in two rows and two columns
show(grid)
# Out:
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
#
#   FG3M stats:
#   Winning Percentage Change Per One: 1.8480732090002474%
#   r: 0.13151667978573747
#   r^2: 0.01729663706186421
#   standard deviation: 0.002739272867111525
#
#   FG3A stats:
#   Winning Percentage Change Per One: 0.5547701619161521%
#   r: 0.10172090191187427
#   r^2: 0.010347141885765148
#   standard deviation: 0.0010669156210542927
#
#   FG3_PCT stats:
#   Winning Percentage Change Per One: 9.386353022641094%
#   r: 0.09553813063990049
#   r^2: 0.009127534406166694
#   standard deviation: 0.01923157109153809
#
#   FTM stats:
#   Winning Percentage Change Per One: 0.6101709195220125%
#   r: 0.07910176165720396
#   r^2: 0.006257088697273103
#   standard deviation: 0.0015121264545677748
#
#   FTA stats:
#   Winning Percentage Change Per One: 0.45361799606877296%
#   r: 0.07290840577565696
#   r^2: 0.00531563563274785
#   standard deviation: 0.0012202282042908658
#
#   FT_PCT stats:
#   Winning Percentage Change Per One: 8.481837631587627%
#   r: 0.05653163884646765
#   r^2: 0.00319582619066745
#   standard deviation: 0.02945703578261939
#
#   OREB stats:
#   Winning Percentage Change Per One: -0.38236960674158843%
#   r: -0.028256615760385916
#   r^2: 0.0007984363342300897
#   standard deviation: 0.002659962479007268
#
#   DREB stats:
#   Winning Percentage Change Per One: 0.7763821721374713%
#   r: 0.11456307583060658
#   r^2: 0.013124698343769314
#   standard deviation: 0.0013238774013528444
#
#   REB stats:
#   Winning Percentage Change Per One: 0.3419123972850625%
#   r: 0.0711732872527276
#   r^2: 0.005065636818359278
#   standard deviation: 0.0009422817466458828
#
#   AST stats:
#   Winning Percentage Change Per One: 0.5577844974414583%
#   r: 0.09377513728951845
#   r^2: 0.008793776373668034
#   standard deviation: 0.0011645187376165523
#
#   TOV stats:
#   Winning Percentage Change Per One: -0.6383143515973204%
#   r: -0.037841712833958936
#   r^2: 0.0014319952302078124
#   standard deviation: 0.0033146554127506064
#
#   STL stats:
#   Winning Percentage Change Per One: 3.2258375579925334%
#   r: 0.10270796336224648
#   r^2: 0.010548925738020565
#   standard deviation: 0.006143576612462285
#
#   BLK stats:
#   Winning Percentage Change Per One: 2.136769514572383%
#   r: 0.09805375098090238
#   r^2: 0.009614538081424815
#   standard deviation: 0.0042646297775208244
#
#   BLKA stats:
#   Winning Percentage Change Per One: -7.833753236227246%
#   r: -0.19071097756506242
#   r^2: 0.03637067696382174
#   standard deviation: 0.007929301618293192
#
#   PF stats:
#   Winning Percentage Change Per One: -2.090024903866906%
#   r: -0.09128613482269562
#   r^2: 0.008333158410867363
#   standard deviation: 0.004483480424004665
#
#   PFD stats:
#   Winning Percentage Change Per One: 0.45296840842250974%
#   r: 0.06661370664909684
#   r^2: 0.004437385913531928
#   standard deviation: 0.0013342104660728341
#
#   PTS stats:
#   Winning Percentage Change Per One: 0.29019720950959205%
#   r: 0.12177302967684447
#   r^2: 0.014828670756677645
#   standard deviation: 0.00046514005794827835
#
#   PLUS_MINUS stats:
#   Winning Percentage Change Per One: 3.5785226062764206%
#   r: 0.9765425582240793
#   r^2: 0.9536353680228293
#   standard deviation: 0.00015516427568371748
#
#   DD2 stats:
#   Winning Percentage Change Per One: 0.07716588215853835%
#   r: 0.08755902180329196
#   r^2: 0.007666582299149357
#   standard deviation: 0.00017263902415954867
#
#   TD3 stats:
#   Winning Percentage Change Per One: 0.5156868578935934%
#   r: 0.09315419331500689
#   r^2: 0.008677703732169674
#   standard deviation: 0.0010838690900477116
#
#   AGE stats:
#   Winning Percentage Change Per One: 1.0011052141745225%
#   r: 0.3094364419463457
#   r^2: 0.09575091160441415
#   standard deviation: 0.0006049758580532476
#
#   GP stats:
#   Winning Percentage Change Per One: 0.09560957906099515%
#   r: 0.04737836013746326
#   r^2: 0.0022447090093151672
#   standard deviation: 0.0003963867608299578
#
#   MIN stats:
#   Winning Percentage Change Per One: 0.22534003782011996%
#   r: 0.06799042852751754
#   r^2: 0.00462269837135547
#   standard deviation: 0.0006502347727477668
#
#   E_OFF_RATING stats:
#   Winning Percentage Change Per One: 1.562502613098432%
#   r: 0.6072461007107748
#   r^2: 0.36874782682844043
#   standard deviation: 0.00040201587254852197
#
#   OFF_RATING stats:
#   Winning Percentage Change Per One: 1.4899808279751392%
#   r: 0.5866168880088296
#   r^2: 0.34411937329716374
#   standard deviation: 0.00040450534053358553
#
#   sp_work_OFF_RATING stats:
#   Winning Percentage Change Per One: 1.4899808279751392%
#   r: 0.5866168880088296
#   r^2: 0.34411937329716374
#   standard deviation: 0.00040450534053358553
#
#   E_DEF_RATING stats:
#   Winning Percentage Change Per One: -1.3652271678407024%
#   r: -0.5020875693119817
#   r^2: 0.25209192725761403
#   standard deviation: 0.000462418609075181
#
#   DEF_RATING stats:
#   Winning Percentage Change Per One: -1.28328689790794%
#   r: -0.47565464302865024
#   r^2: 0.22624733943471267
#   standard deviation: 0.00046667962179953147
#
#   sp_work_DEF_RATING stats:
#   Winning Percentage Change Per One: -1.28328689790794%
#   r: -0.47565464302865024
#   r^2: 0.22624733943471267
#   standard deviation: 0.00046667962179953147
#
#   E_NET_RATING stats:
#   Winning Percentage Change Per One: 2.299341729909041%
#   r: 0.9836750072392162
#   r^2: 0.967616519867072
#   standard deviation: 8.271787772040192e-05
#
#   NET_RATING stats:
#   Winning Percentage Change Per One: 2.375399646272569%
#   r: 0.9835114631487346
#   r^2: 0.9672947981449648
#   standard deviation: 8.589174340750032e-05
#
#   sp_work_NET_RATING stats:
#   Winning Percentage Change Per One: 2.375399646272569%
#   r: 0.9835114631487346
#   r^2: 0.9672947981449648
#   standard deviation: 8.589174340750032e-05
#
#   AST_PCT stats:
#   Winning Percentage Change Per One: 7.540158840463369%
#   r: 0.057200180899855964
#   r^2: 0.003271860694976247
#   standard deviation: 0.02587957809258648
#
#   AST_TO stats:
#   Winning Percentage Change Per One: 2.7160361394877843%
#   r: 0.16086328828144927
#   r^2: 0.025876997516720655
#   standard deviation: 0.0032769607630653073
#
#   AST_RATIO stats:
#   Winning Percentage Change Per One: 0.14332295399242972%
#   r: 0.0857274245330434
#   r^2: 0.007349191317068651
#   standard deviation: 0.0003275517802576662
#
#   OREB_PCT stats:
#   Winning Percentage Change Per One: -7.516317428425754%
#   r: -0.017583394507418276
#   r^2: 0.0003091757624035072
#   standard deviation: 0.08404676180467227
#
#   DREB_PCT stats:
#   Winning Percentage Change Per One: 11.713436983602493%
#   r: 0.05001567589049313
#   r^2: 0.0025015678347828562
#   standard deviation: 0.04599599880388978
#
#   REB_PCT stats:
#   Winning Percentage Change Per One: 15.615661603107576%
#   r: 0.049057341986671665
#   r^2: 0.0024066228027972585
#   standard deviation: 0.06251998912707585
#
#   TM_TOV_PCT stats:
#   Winning Percentage Change Per One: -1.091506185313487%
#   r: -0.1782898558706819
#   r^2: 0.03178727270638853
#   standard deviation: 0.0011845971966121635
#
#   E_TOV_PCT stats:
#   Winning Percentage Change Per One: -1.087504822936722%
#   r: -0.17829465019321405
#   r^2: 0.03178898228752056
#   standard deviation: 0.0011802217921828419
#
#   EFG_PCT stats:
#   Winning Percentage Change Per One: 96.5972675934721%
#   r: 0.3360198608290986
#   r^2: 0.11290934687160681
#   standard deviation: 0.05324387260654734
#
#   TS_PCT stats:
#   Winning Percentage Change Per One: 105.8342528419243%
#   r: 0.34008048076919023
#   r^2: 0.11565473340020356
#   standard deviation: 0.05754945428670921
#
#   USG_PCT stats:
#   Winning Percentage Change Per One: 6.602463490682391%
#   r: 0.026359834443833954
#   r^2: 0.000694840871906335
#   standard deviation: 0.04923774270909344
#
#   E_USG_PCT stats:
#   Winning Percentage Change Per One: 6.829096465298851%
#   r: 0.027733752273399376
#   r^2: 0.000769161015162285
#   standard deviation: 0.048403110320483375
#
#   E_PACE stats:
#   Winning Percentage Change Per One: -0.0973990988554574%
#   r: -0.029275810013264666
#   r^2: 0.0008570730519327677
#   standard deviation: 0.00065395154103209
#
#   PACE stats:
#   Winning Percentage Change Per One: -0.11367291479534666%
#   r: -0.033458461728059025
#   r^2: 0.0011194686612079905
#   standard deviation: 0.000667718701547516
#
#   PACE_PER40 stats:
#   Winning Percentage Change Per One: -0.1363887254893212%
#   r: -0.033452922596869245
#   r^2: 0.0011190980302721249
#   standard deviation: 0.0008012849762555215
#
#   sp_work_PACE stats:
#   Winning Percentage Change Per One: -0.11367291479534666%
#   r: -0.033458461728059025
#   r^2: 0.0011194686612079905
#   standard deviation: 0.000667718701547516
#
#   PIE stats:
#   Winning Percentage Change Per One: 115.81552953073428%
#   r: 0.2765163079985189
#   r^2: 0.07646126858913177
#   standard deviation: 0.07915153545202007
#
#   POSS stats:
#   Winning Percentage Change Per One: 0.0018465730068731605%
#   r: 0.08995132718452004
#   r^2: 0.008091241262256573
#   standard deviation: 4.0205041022259364e-06
#
#   FGM stats:
#   Winning Percentage Change Per One: 0.011779335023795898%
#   r: 0.1249903791293628
#   r^2: 0.01562259487490185
#   standard deviation: 1.8386994520049443e-05
#
#   FGA stats:
#   Winning Percentage Change Per One: 0.002492499301488932%
#   r: 0.05537822216746786
#   r^2: 0.0030667474904294283
#   standard deviation: 8.837202703542879e-06
#
#   FGM_PG stats:
#   Winning Percentage Change Per One: 0.7354775704269536%
#   r: 0.10788513190172497
#   r^2: 0.011639201685452594
#   standard deviation: 0.0013327581020658463
#
#   FGA_PG stats:
#   Winning Percentage Change Per One: 0.1257851918712499%
#   r: 0.03864322025409227
#   r^2: 0.001493298471606287
#   standard deviation: 0.0006396132295947697
#
#   FG_PCT stats:
#   Winning Percentage Change Per One: 52.670284646090145%
#   r: 0.20289885007790398
#   r^2: 0.041167943362935756
#   standard deviation: 0.0499853908287664
